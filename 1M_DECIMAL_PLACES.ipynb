# %% [markdown]
# # Frequency of Digits in First 1 Million Decimal Places in Pi (π)

# %%
from mpmath import mp, pi, e
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
mp.dps = 1000001

# %%
pi_dec = str(pi).split('.')[1]
#pi_dec
# Out:
# '...'

# %%
pi_dict = dict()

for i in pi_dec:
    if i in pi_dict: pi_dict[i]+=1
    else: pi_dict[i]=0

pi_dict
# Out:
# {'1': 99757,
#  '4': 100229,
#  '5': 100358,
#  '9': 100105,
#  '2': 100025,
#  '6': 99547,
#  '3': 100228,
#  '8': 99984,
#  '7': 99799,
#  '0': 99958}

# %%
pi_df = pd.DataFrame.from_dict(pi_dict, orient='index').rename(columns={0:'Repetitions'})

# %%
plt.figure(figsize=(20,10))
plt.title('\nFREQUENCY OF DIGITS IN THE FIRST 1 MILLION DECIMAL PLACES OF π\n', fontsize=30)
plt.yscale('log')
plot = sns.lineplot(data=pi_df)
plot.set_xlabel('DIGITS',fontsize=20)
plot.set_ylabel('FREQUENCY', fontsize=20)
plt.xticks(fontsize=16)
plt.legend(fontsize='xx-large')
plt.show()

# %%
(pi_df/10000).sort_index().rename(columns={'Repetitions':'% Repetitions'})
# Out:
#    % Repetitions
# 0         9.9958
# 1         9.9757
# 2        10.0025
# 3        10.0228
# 4        10.0229
# 5        10.0358
# 6         9.9547
# 7         9.9799
# 8         9.9984
# 9        10.0105

# %% [markdown]
# # Frequency of Digits in First 1 Million Decimal Places in Euler's Number (e)

# %%
e_dec = str(e).split('.')[1]
#e_dec
# Out:
# '...'

# %%
e_dict = dict()

for i in e_dec:
    if i in e_dict: e_dict[i]+=1
    else: e_dict[i]=0

e_dict
# Out:
# {'7': 99909,
#  '1': 100131,
#  '8': 99812,
#  '2': 99844,
#  '4': 100388,
#  '5': 100086,
#  '9': 99691,
#  '0': 99424,
#  '3': 100227,
#  '6': 100478}

# %%
e_df = pd.DataFrame.from_dict(e_dict, orient='index').rename(columns={0:'Repetitions'})

# %%
plt.figure(figsize=(20,10))
plt.title('\nFREQUENCY OF DIGITS IN THE FIRST 1 MILLION DECIMAL PLACES OF e\n', fontsize=30)
plt.yscale('log')
plot = sns.lineplot(data=e_df)
plot.set_xlabel('DIGITS',fontsize=20)
plot.set_ylabel('FREQUENCY', fontsize=20)
plt.xticks(fontsize=16)
plt.legend(fontsize='xx-large')
plt.show()

# %%
(e_df/10000).sort_index().rename(columns={'Repetitions':'% Repetitions'})
# Out:
#    % Repetitions
# 0         9.9424
# 1        10.0131
# 2         9.9844
# 3        10.0227
# 4        10.0388
# 5        10.0086
# 6        10.0478
# 7         9.9909
# 8         9.9812
# 9         9.9691
